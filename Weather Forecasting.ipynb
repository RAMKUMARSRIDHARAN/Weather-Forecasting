# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#loading dataset
Weather_Forecast = pd.read_csv("D:\DS with Py\Data Science Datasets\Weather_Dataset.csv")
Weather_Forecast
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
#Data Informatiom
Weather_Forecast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
#Data Describing
Weather_Forecast.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
#Checking null values
Weather_Forecast.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
plt.figure(figsize=(12, 40))
sns.countplot(data=Weather_Forecast, y='Daily Summary', order=Weather_Forecast['Daily Summary'].value_counts().index)
plt.title("Distribution of Daily Summary (Weather)")
plt.xlabel("Density")
plt.ylabel("Daily Summary")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Data Analysis

# %%
Weather_Forecast.shape
# Out:
# (96453, 12)

# %%
Weather_Forecast.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %% [markdown]
# ## Unique columns for Each columns in weather Dataset

# %%
# Iterate through each column
for column in Weather_Forecast.columns:
    # Get unique values and their counts for the column
    unique_values = Weather_Forecast[column].value_counts()
    
    print(f"\nUnique values for column '{column}':")
    print("-" * 100)
    print(unique_values)
# Out:
# Unique values for column 'Formatted Date':
# ----------------------------------------------------------------------------------------------------
# Formatted Date
# 2010-08-02 00:00:00.000 +0200    2
# 2010-08-02 12:00:00.000 +0200    2
# 2010-08-02 03:00:00.000 +0200    2
# 2010-08-02 04:00:00.000 +0200    2
# 2010-08-02 05:00:00.000 +0200    2
#                                 ..
# 2009-03-09 22:00:00.000 +0100    1
# 2009-03-09 21:00:00.000 +0100    1
# 2009-03-09 20:00:00.000 +0100    1
# 2009-03-09 19:00:00.000 +0100    1
# 2016-09-09 23:00:00.000 +0200    1
# Name: count, Length: 96429, dtype: int64
#
# Unique values for column 'Summary':
# ----------------------------------------------------------------------------------------------------
# Summary
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# ...

# %% [markdown]
# ## Duplicates Detecting for each columns

# %%
# Iterate through each column
for column in Weather_Forecast.columns:
    # Get unique values and their counts for the column
    duplicated_columns = Weather_Forecast[column].duplicated()
    
    print(f"\duplicated values for column '{column}':")
    print("-" * 100)
    print(duplicated_columns.sum())
# Out:
# \duplicated values for column 'Formatted Date':
# ----------------------------------------------------------------------------------------------------
# 24
# \duplicated values for column 'Summary':
# ----------------------------------------------------------------------------------------------------
# 96426
# \duplicated values for column 'Precip Type':
# ----------------------------------------------------------------------------------------------------
# 96450
# \duplicated values for column 'Temperature (C)':
# ----------------------------------------------------------------------------------------------------
# 88879
# \duplicated values for column 'Apparent Temperature (C)':
# ----------------------------------------------------------------------------------------------------
# 87469
# \duplicated values for column 'Humidity':
# ----------------------------------------------------------------------------------------------------
# 96363
# ...

# %% [markdown]
# ## Minimum and maximum for each columns with for loop

# %%
# Iterate through each column
for column in Weather_Forecast.columns:
    # Check if the column is numeric
    if pd.api.types.is_numeric_dtype(Weather_Forecast[column]):
        min_value = Weather_Forecast[column].min()
        max_value = Weather_Forecast[column].max()
        print(f"\nMinimum and Maximum values for column '{column}':")
        print("-" * 100)
        print(f"Min: {min_value}")
        print(f"Max: {max_value}")
    else:
        print(f"\nColumn '{column}' is not numeric, skipping min/max calculation.")
# Out:
# Column 'Formatted Date' is not numeric, skipping min/max calculation.
#
# Column 'Summary' is not numeric, skipping min/max calculation.
#
# Column 'Precip Type' is not numeric, skipping min/max calculation.
#
# Minimum and Maximum values for column 'Temperature (C)':
# ----------------------------------------------------------------------------------------------------
# Min: -21.822222222222223
# Max: 39.90555555555555
#
# Minimum and Maximum values for column 'Apparent Temperature (C)':
# ----------------------------------------------------------------------------------------------------
# Min: -27.716666666666665
# Max: 39.34444444444444
#
# Minimum and Maximum values for column 'Humidity':
# ----------------------------------------------------------------------------------------------------
# Min: 0.0
# Max: 1.0
#
# Minimum and Maximum values for column 'Wind Speed (km/h)':
# ----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Unique value for Each columns

# %%
# Get the number of distinct (unique) values in each column
Weather_Forecast['Formatted Date'].unique()
# Out:
# array(['2006-04-01 00:00:00.000 +0200', '2006-04-01 01:00:00.000 +0200',
#        '2006-04-01 02:00:00.000 +0200', ...,
#        '2016-09-09 21:00:00.000 +0200', '2016-09-09 22:00:00.000 +0200',
#        '2016-09-09 23:00:00.000 +0200'], dtype=object)

# %%
# Get the number of distinct (unique) values in each column
Weather_Forecast['Summary'].unique()
# Out:
# array(['Partly Cloudy', 'Mostly Cloudy', 'Overcast', 'Foggy',
#        'Breezy and Mostly Cloudy', 'Clear', 'Breezy and Partly Cloudy',
#        'Breezy and Overcast', 'Humid and Mostly Cloudy',
#        'Humid and Partly Cloudy', 'Windy and Foggy', 'Windy and Overcast',
#        'Breezy and Foggy', 'Windy and Partly Cloudy', 'Breezy',
#        'Dry and Partly Cloudy', 'Windy and Mostly Cloudy',
#        'Dangerously Windy and Partly Cloudy', 'Dry', 'Windy',
#        'Humid and Overcast', 'Light Rain', 'Drizzle', 'Windy and Dry',
#        'Dry and Mostly Cloudy', 'Breezy and Dry', 'Rain'], dtype=object)

# %%
# Get the number of distinct (unique) values in each column
Weather_Forecast['Precip Type'].unique()
# Out:
# array(['rain', 'snow', nan], dtype=object)

# %%
# Get the number of distinct (unique) values in each column
Weather_Forecast['Temperature (C)'].unique()
# Out:
# array([ 9.47222222,  9.35555556,  9.37777778, ..., 28.47222222,
#        28.33888889, 30.60555556])

# %%
# Get the number of distinct (unique) values in each column
Weather_Forecast['Apparent Temperature (C)'].unique()
# Out:
# array([ 7.38888889,  7.22777778,  9.37777778, ..., 12.14444444,
#         9.73888889,  9.23333333])

# %%
# Get the number of distinct (unique) values in each column
Weather_Forecast['Humidity'].unique()
# Out:
# array([0.89, 0.86, 0.83, 0.85, 0.95, 0.82, 0.72, 0.67, 0.54, 0.55, 0.51,
#        0.47, 0.46, 0.6 , 0.63, 0.69, 0.7 , 0.77, 0.76, 0.79, 0.62, 0.66,
#        0.8 , 0.78, 0.61, 0.52, 0.4 , 0.37, 0.36, 0.43, 0.5 , 0.53, 0.58,
#        0.59, 0.87, 0.93, 0.84, 0.73, 0.71, 0.74, 0.81, 0.9 , 0.99, 0.96,
#        0.75, 0.88, 0.65, 0.91, 0.94, 0.92, 0.44, 0.56, 0.68, 0.64, 0.48,
#        0.57, 0.98, 1.  , 0.38, 0.41, 0.45, 0.49, 0.32, 0.42, 0.35, 0.39,
#        0.97, 0.34, 0.33, 0.31, 0.3 , 0.29, 0.27, 0.28, 0.26, 0.24, 0.25,
#        0.23, 0.19, 0.17, 0.2 , 0.15, 0.18, 0.22, 0.14, 0.21, 0.16, 0.13,
#        0.  , 0.12])

# %%
# Get the number of distinct (unique) values in each column
Weather_Forecast['Wind Speed (km/h)'].unique()
# Out:
# array([14.1197, 14.2646,  3.9284, ..., 37.0622, 35.5971, 30.751 ])

# %%
# Get the number of distinct (unique) values in each column
Weather_Forecast['Wind Bearing (degrees)'].unique()
# Out:
# array([251., 259., 204., 269., 258., 260., 279., 290., 316., 281., 289.,
#        262., 288., 230., 163., 139., 147., 160., 152., 150., 149., 180.,
#        161., 135., 141., 151., 169., 170., 187., 179., 162., 159., 168.,
#         32., 140., 103., 113., 129., 207., 153.,   4., 341.,  15., 348.,
#        321., 311., 339., 340., 330.,  19., 277.,   9.,   0., 350., 349.,
#        338., 320., 310., 328.,  20.,  28.,  11., 326., 309., 193., 273.,
#        300., 307., 319., 318., 243., 177., 172., 142., 130., 359., 166.,
#        145., 178., 223., 240., 231., 214., 222., 241., 235., 238., 211.,
#        221., 215., 224., 358.,   8.,  59.,  63.,  65., 146., 305., 327.,
#        271., 297., 301., 308., 272., 351., 175., 138., 158., 132., 209.,
#        250., 295., 280., 270., 239., 242., 266., 278., 325., 282., 274.,
#        255.,  46., 284., 283., 313., 345.,  16., 332.,  12.,  39.,   3.,
#         33.,  24.,  25.,  31.,  47.,  67.,  60., 144.,  57.,   2.,  18.,
# ...

# %%
# Get the number of distinct (unique) values in each column
Weather_Forecast['Visibility (km)'].unique()
# Out:
# array([1.58263e+01, 1.49569e+01, 9.98200e+00, 1.12056e+01, 1.14471e+01,
#        1.12700e+01, 1.10285e+01, 6.19850e+00, 8.05000e+00, 1.03523e+01,
#        6.69760e+00, 9.90150e+00, 5.97310e+00, 1.08031e+01, 1.06743e+01,
#        1.08192e+01, 1.07548e+01, 1.08997e+01, 1.08514e+01, 1.10768e+01,
#        1.08836e+01, 7.61530e+00, 2.65650e+00, 3.81570e+00, 4.49190e+00,
#        4.44360e+00, 5.68330e+00, 3.10730e+00, 3.20390e+00, 1.40553e+01,
#        6.11800e+00, 6.16630e+00, 7.96950e+00, 6.34340e+00, 1.05455e+01,
#        1.49086e+01, 1.50052e+01, 1.58746e+01, 1.00464e+01, 1.00303e+01,
#        1.19784e+01, 1.41680e+01, 5.92480e+00, 1.22360e+00, 7.21280e+00,
#        1.11251e+01, 1.33791e+01, 1.13988e+01, 1.12861e+01, 1.56975e+01,
#        1.48764e+01, 6.84250e+00, 1.53594e+01, 4.29870e+00, 4.12160e+00,
#        4.76560e+00, 2.93020e+00, 5.84430e+00, 9.61170e+00, 9.67610e+00,
#        2.01250e+00, 5.21640e+00, 1.45866e+01, 1.56009e+01, 1.47154e+01,
# ...

# %%
# Get the number of distinct (unique) values in each column
Weather_Forecast['Loud Cover'].unique()
# Out:
# array([0.])

# %%
# Get the number of distinct (unique) values in each column
Weather_Forecast['Pressure (millibars)'].unique()
# Out:
# array([1015.13, 1015.63, 1015.94, ...,  998.11,  998.52,  997.59])

# %%
# Get the number of distinct (unique) values in each column
Weather_Forecast['Daily Summary'].unique()
# Out:
# array(['Partly cloudy throughout the day.',
#        'Mostly cloudy throughout the day.', 'Foggy in the evening.',
#        'Foggy overnight and breezy in the morning.',
#        'Overcast throughout the day.', 'Partly cloudy until night.',
#        'Mostly cloudy until night.',
#        'Foggy starting overnight continuing until morning.',
#        'Foggy in the morning.', 'Partly cloudy until evening.',
#        'Partly cloudy starting in the morning.',
#        'Mostly cloudy starting overnight continuing until night.',
#        'Mostly cloudy until evening.',
#        'Partly cloudy starting in the morning continuing until evening.',
#        'Partly cloudy starting in the afternoon.',
#        'Partly cloudy starting overnight.',
#        'Partly cloudy until morning.',
#        'Partly cloudy starting overnight continuing until night.',
#        'Partly cloudy starting in the afternoon continuing until night.',
#        'Mostly cloudy starting overnight.',
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Handlng missing values

# %%
Weather_Forecast['Precip Type'] = Weather_Forecast['Precip Type'].fillna('Unknown')

# %%
Weather_Forecast.isnull().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %% [markdown]
# # Time Series Algorithm

# %%
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA

# %%
# Exploratory Data Analysis (EDA)
plt.figure(figsize=(12, 6))
plt.plot(Weather_Forecast['Precip Type'])  # Replace with relevant column name
plt.title('Time Series Plot')
plt.xlabel('Date')
plt.ylabel('Temperature (C)')
plt.show()

# %%
# Check for Stationarity
result = adfuller(Weather_Forecast['Temperature (C)'])  # Use specific column for analysis
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:', result[4])
# Out:
# ADF Statistic: -10.140083406906351
# p-value: 8.465719841306251e-18
# Critical Values: {'1%': -3.430417847426096, '5%': -2.8615699874869773, '10%': -2.5667859612921466}

# %%
# Decomposition
decomposition = seasonal_decompose(Weather_Forecast['Temperature (C)'], model='additive', period=365)  # Specify period if necessary
decomposition.plot()
plt.show()

# %%
# Autocorrelation and Partial Autocorrelation Plots
plot_acf(Weather_Forecast['Temperature (C)'])
plot_pacf(Weather_Forecast['Temperature (C)'])
plt.show()

# %%
# Model Building and Forecasting
model = ARIMA(Weather_Forecast['Temperature (C)'], order=(5,1,0))  # Example ARIMA model parameters
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:        Temperature (C)   No. Observations:                96453
# Model:                 ARIMA(5, 1, 0)   Log Likelihood             -172422.136
# Date:                Wed, 20 Nov 2024   AIC                         344856.271
# Time:                        11:40:48   BIC                         344913.132
# Sample:                             0   HQIC                        344873.555
#                               - 96453
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2198      0.002    131.782      0.000       0.217       0.223
# ar.L2          0.2054      0.002     92.013      0.000       0.201       0.210
# ar.L3          0.0897      0.003     29.492      0.000       0.084       0.096
# ...

# %%
# Visualize the forecast (Note: Forecasting will require predicting future values)
forecast = model_fit.forecast(steps=10)  # Forecast next 10 steps
plt.figure(figsize=(12, 6))
plt.plot(Weather_Forecast['Temperature (C)'], label='Observed')
plt.plot(range(len(Weather_Forecast), len(Weather_Forecast) + 10), forecast, label='Forecast', color='red')
plt.xlabel('Date')
plt.ylabel('Temperature (C)')
plt.legend()
plt.title('Temperature Forecast')
plt.show()

# %% [markdown]
# # Using Prophet

# %%
pip install prophet
# Out:
# ...
#
# ...

# %%
#importing Prophet 
from prophet import Prophet

#loading dataset
Weather_Forecast = pd.read_csv("D:\DS with Py\Data Science Datasets\Weather_Dataset.csv")
Weather_Forecast
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
model = Prophet()
model.fit(Weather_Forecast)

# %%
future = model.make_future_dataframe(periods=365)
future.tail()

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
from prophet.plot import plot_plotly, plot_components_plotly

plot_plotly(m, forecast)

# %%
plot_components_plotly(m, forecast)
